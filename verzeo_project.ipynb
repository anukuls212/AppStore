# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('appstore_games (2).csv')

# %%
df.head()
# Out:
#                                                  URL         ID  \
# 0   https://apps.apple.com/us/app/sudoku/id284921427  284921427
# 1  https://apps.apple.com/us/app/reversi/id284926400  284926400
# 2  https://apps.apple.com/us/app/morocco/id284946595  284946595
# 3  https://apps.apple.com/us/app/sudoku-free/id28...  285755462
# 4  https://apps.apple.com/us/app/senet-deluxe/id2...  285831220
#
#             Name Subtitle                                           Icon URL  \
# 0         Sudoku      NaN  https://is2-ssl.mzstatic.com/image/thumb/Purpl...
# 1        Reversi      NaN  https://is4-ssl.mzstatic.com/image/thumb/Purpl...
# 2        Morocco      NaN  https://is5-ssl.mzstatic.com/image/thumb/Purpl...
# 3  Sudoku (Free)      NaN  https://is3-ssl.mzstatic.com/image/thumb/Purpl...
# 4   Senet Deluxe      NaN  https://is1-ssl.mzstatic.com/image/thumb/Purpl...
#
#    Average User Rating  User Rating Count  Price In-app Purchases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   URL                           17007 non-null  object
#  1   ID                            17007 non-null  int64
#  2   Name                          17007 non-null  object
#  3   Subtitle                      5261 non-null   object
#  4   Icon URL                      17007 non-null  object
#  5   Average User Rating           7561 non-null   float64
#  6   User Rating Count             7561 non-null   float64
#  7   Price                         16983 non-null  float64
#  8   In-app Purchases              7683 non-null   object
#  9   Description                   17007 non-null  object
#  10  Developer                     17007 non-null  object
#  11  Age Rating                    17007 non-null  object
# ...

# %%
df.describe()
# Out:
#                  ID  Average User Rating  User Rating Count         Price  \
# count  1.700700e+04          7561.000000       7.561000e+03  16983.000000
# mean   1.059614e+09             4.060905       3.306531e+03      0.813419
# std    2.999676e+08             0.751428       4.232256e+04      7.835732
# min    2.849214e+08             1.000000       5.000000e+00      0.000000
# 25%    8.996543e+08             3.500000       1.200000e+01      0.000000
# 50%    1.112286e+09             4.500000       4.600000e+01      0.000000
# 75%    1.286983e+09             4.500000       3.090000e+02      0.000000
# max    1.475077e+09             5.000000       3.032734e+06    179.990000
#
#                Size
# count  1.700600e+04
# mean   1.157064e+08
# std    2.036477e+08
# min    5.132800e+04
# 25%    2.295014e+07
# 50%    5.676895e+07
# 75%    1.330271e+08
# max    4.005591e+09

# %%
# Method 1:Removing the null values and checking using the Heatmap that no null values are left.

# %%
sns.heatmap(df.isnull(),cbar = False,yticklabels = False, cmap='viridis')

# %%
df.columns
# Out:
# Index(['URL', 'ID', 'Name', 'Subtitle', 'Icon URL', 'Average User Rating',
#        'User Rating Count', 'Price', 'In-app Purchases', 'Description',
#        'Developer', 'Age Rating', 'Languages', 'Size', 'Primary Genre',
#        'Genres', 'Original Release Date', 'Current Version Release Date'],
#       dtype='object')

# %%
mod = df.drop(['URL', 'ID', 'Subtitle', 'Icon URL','Description','Developer','Languages', 'Size',
         'Original Release Date', 'Current Version Release Date'] , axis = 1)

# %%
sns.heatmap(mod.isnull())

# %%
df.isnull().sum()
# Out:
# URL                                 0
# ID                                  0
# Name                                0
# Subtitle                        11746
# Icon URL                            0
# Average User Rating              9446
# User Rating Count                9446
# Price                              24
# In-app Purchases                 9324
# Description                         0
# Developer                           0
# Age Rating                          0
# Languages                          60
# Size                                1
# Primary Genre                       0
# Genres                              0
# Original Release Date               0
# Current Version Release Date        0
# dtype: int64

# %%
mod.head(10)
# Out:
#                              Name  Average User Rating  User Rating Count  \
# 0                          Sudoku                  4.0             3553.0
# 1                         Reversi                  3.5              284.0
# 2                         Morocco                  3.0             8376.0
# 3                   Sudoku (Free)                  3.5           190394.0
# 4                    Senet Deluxe                  3.5               28.0
# 5  Sudoku - Classic number puzzle                  3.0               47.0
# 6                     Gravitation                  2.5               35.0
# 7                          Colony                  2.5              125.0
# 8                           Carte                  2.5               44.0
# 9                "Barrels O' Fun"                  2.5              184.0
#
#    Price In-app Purchases Age Rating Primary Genre  \
# 0   2.99              NaN         4+         Games
# ...

# %%
plt.figure(figsize=(12,4))
sns.countplot(mod['Average User Rating'])

# %%
mod['Primary Genre'].value_counts()
# Out:
# Games                16286
# Education              222
# Entertainment          198
# Utilities               77
# Sports                  60
# Reference               32
# Stickers                29
# Finance                 18
# Business                16
# Productivity            15
# Lifestyle               10
# Social Networking        9
# Book                     9
# News                     7
# Health & Fitness         5
# Food & Drink             4
# Music                    3
# Navigation               3
# Medical                  2
# Shopping                 1
# Travel                   1
# Name: Primary Genre, dtype: int64

# %%
#plt.figure(figsize=(12,10))
#sns.boxplot(x='Primary Genre',y='Average User Rating',data=df)

# %%
plt.figure(figsize=(12,7))
sns.countplot(y = mod['Primary Genre'])

# %%
sns.countplot(mod['Price']==0)

# %%
mod["User Rating Count"].mean()
# Out:
# 3306.5312789313584

# %%
mod[mod['Average User Rating'].isnull()] = 0.0

# %%
mod['Average User Rating'].isnull().sum()
# Out:
# 0

# %%
# to check the number of people who have not given a rating
plt.figure(figsize=(12,4))
sns.countplot(mod['Average User Rating'])

# %%
mod = mod[mod['Average User Rating']>mod['Average User Rating'].mean()]

# %%
mod.isnull().sum()
# Out:
# Name                      0
# Average User Rating       0
# User Rating Count         0
# Price                     0
# In-app Purchases       2879
# Age Rating                0
# Primary Genre             0
# Genres                    0
# dtype: int64

# %%
sns.heatmap(mod.isnull())

# %%
# removing the in-app purchases column
mod.drop(['In-app Purchases'],axis=1,inplace = True)
# Out:
# C:\Users\Intel\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
# the final heatmap that shows that there is no null value left in the data called mod
sns.heatmap(mod.isnull())

# %%
df_games = mod[mod['Primary Genre'] == 'Games']

# %%
df_games = df_games.sort_values(by=["Average User Rating","User Rating Count"],ascending=False)
df_games.head()
# Out:
#                                     Name  Average User Rating  \
# 12473     Cash, Inc. Fame & Fortune Game                  5.0
# 6089                           Egg, Inc.                  5.0
# 14155                          AFK Arena                  5.0
# 8388   South Park: Phone Destroyer\u2122                  5.0
# 13261         From Zero to Hero: Cityman                  5.0
#
#        User Rating Count  Price  \
# 12473           374772.0    0.0
# 6089            174591.0    0.0
# 14155           156766.0    0.0
# 8388            156044.0    0.0
# 13261           146729.0    0.0
#
#                                         In-app Purchases Age Rating  \
# 12473  1.99, 4.99, 0.99, 9.99, 3.99, 19.99, 2.99, 4.9...         4+
# 6089           4.99, 7.99, 4.99, 19.99, 9.99, 0.99, 3.99         4+
# 14155  4.99, 0.99, 9.99, 19.99, 24.99, 14.99, 49.99, ...         9+
# 8388   4.99, 5.99, 9.99, 19.99, 4.99, 49.99, 0.99, 1....        17+
# ...

# %%
#sns.countplot(y = 'Price', x ='Average User Rating',data = mod)

# %%
df_games['Price'].value_counts()
# Out:
# 0.00     6062
# 0.99      331
# 2.99      238
# 1.99      187
# 4.99      177
# 3.99       96
# 9.99       45
# 5.99       26
# 6.99       26
# 8.99       12
# 7.99       10
# 19.99       5
# 11.99       3
# 12.99       2
# 14.99       2
# 16.99       1
# 59.99       1
# Name: Price, dtype: int64

# %%
plt.figure(figsize=(12,4))
sns.countplot(df_games['Price'])

# %%
plt.figure(figsize=(12,4))
sns.countplot(df_games['Average User Rating'])

# %%
df_games['Genres'].value_counts().head(10)
# Out:
# Games, Simulation, Strategy               287
# Games, Strategy, Simulation               287
# Games, Strategy, Action                   260
# Games, Strategy, Puzzle                   259
# Games, Puzzle, Strategy                   217
# Games, Strategy                           215
# Games, Action, Strategy                   206
# Games, Strategy, Role Playing             184
# Games, Role Playing, Strategy             175
# Games, Strategy, Puzzle, Entertainment    138
# Name: Genres, dtype: int64

# %%
# The above shows that the most common genres are games,strategy and Simulation

# %%
# Method 2: Scannning for junk values and then dropping them of.

# %%
# dropping the columns URL, ID, Icon URL
df.drop(columns=["URL","ID","Icon URL"], inplace=True)

# %%
# finding the no. of missing values in each column
df.isna().sum()
# Out:
# Name                                0
# Subtitle                        11746
# Average User Rating              9446
# User Rating Count                9446
# Price                              24
# In-app Purchases                 9324
# Description                         0
# Developer                           0
# Age Rating                          0
# Languages                          60
# Size                                1
# Primary Genre                       0
# Genres                              0
# Original Release Date               0
# Current Version Release Date        0
# dtype: int64

# %%
# scanning for junk values
df["Subtitle"].dropna().head()
# Out:
# 5            Original brain training
# 19    Sudoku, Jigsaw, Killer, Kakuro
# 27           Game of Global Conquest
# 33    For beginners to professionals
# 36               Fun and easy to use
# Name: Subtitle, dtype: object

# %%
# no. of rows in each rating bracket
df["Average User Rating"].value_counts()
# Out:
# 4.5    2861
# 4.0    1722
# 5.0     990
# 3.5     925
# 3.0     514
# 2.5     317
# 2.0     158
# 1.5      60
# 1.0      14
# Name: Average User Rating, dtype: int64

# %%
# plotting the boxplot to understand the outliers
sns.boxplot(df["Average User Rating"])

# %%
# scanning for junk values
df["User Rating Count"].dropna().sort_values().head()
# Out:
# 4891    5.0
# 626     5.0
# 7114    5.0
# 2867    5.0
# 2866    5.0
# Name: User Rating Count, dtype: float64

# %%
plt.figure(figsize=(12,4))
sns.countplot(df['User Rating Count'].dropna())

# %%
# checking the different price brackets
df["Price"].value_counts().sort_index()
# Out:
# 0.00      14212
# 0.99       1078
# 1.99        515
# 2.99        471
# 3.99        163
# 4.99        237
# 5.99         42
# 6.99         32
# 7.99         17
# 8.99         13
# 9.99         88
# 11.99        59
# 12.99         3
# 14.99         4
# 16.99         2
# 18.99         1
# 19.99         9
# 29.99         2
# 36.99         1
# 37.99         1
# 59.99         1
# 99.99         1
# 139.99        1
# 179.99       30
# Name: Price, dtype: int64

# %%
# splitting the string and storing the values as a list
df["Languages"] = df["Languages"].dropna().map(lambda x: x.split(", "))

# %%
# filling the missing value
df["Size"].fillna(method="ffill", inplace=True)

# %%
# converting size in bytes to mega-bytes
df["Size"] = df["Size"].map(lambda x: round(x/(1024 * 1024), 2))
df["Size"].head()
# Out:
# 0    15.12
# 1    11.76
# 2     0.64
# 3    20.55
# 4    33.08
# Name: Size, dtype: float64

# %%
# splitting the string and storing the values as a list
df["Genres"] = df["Genres"].map(lambda x: x.split(", "))
df["Genres"].head()
# Out:
# 0              [Games, Strategy, Puzzle]
# 1               [Games, Strategy, Board]
# 2               [Games, Board, Strategy]
# 3              [Games, Strategy, Puzzle]
# 4    [Games, Strategy, Board, Education]
# Name: Genres, dtype: object

# %%
df["Total In-app Purchases"] = df["In-app Purchases"].dropna().map(lambda x: sum(x))
df["Total In-app Purchases"].dropna().value_counts().head()
# Out:
# 0.99    945
# 2.99    608
# 1.99    562
# 4.99    154
# 1.98    142
# Name: Total In-app Purchases, dtype: int64

# %%
df["Game Genre"] = df[df["Primary Genre"] == "Games"]["Genres"].map(lambda x: x[1])
df["Game Genre"].head()
# Out:
# 0    Strategy
# 1    Strategy
# 2       Board
# 3    Strategy
# 4    Strategy
# Name: Game Genre, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17007 entries, 0 to 17006
# Data columns (total 17 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Name                          17007 non-null  object
#  1   Subtitle                      5261 non-null   object
#  2   Average User Rating           7561 non-null   float64
#  3   User Rating Count             7561 non-null   float64
#  4   Price                         16983 non-null  float64
#  5   In-app Purchases              7683 non-null   object
#  6   Description                   17007 non-null  object
#  7   Developer                     17007 non-null  object
#  8   Age Rating                    17007 non-null  object
#  9   Languages                     16947 non-null  object
#  10  Size                          17007 non-null  float64
#  11  Primary Genre                 17007 non-null  object
# ...

# %%
top_genres = list(df["Primary Genre"].value_counts().head(10).index)

# %%
df[df["Primary Genre"].isin(top_genres)]["Primary Genre"].value_counts().plot.bar(figsize=(8,5))
plt.title("Bar plot of primary genre wise apps")
# Out:
# Text(0.5, 1.0, 'Bar plot of primary genre wise apps')

# %%
# the above plot shows that the games genre is the most popular

# %%
def word_cloud(list_variable):
    fig, ax = plt.subplots(1,3, figsize=(15,4))
    for i, variable in enumerate(list_variable):
        corpus = df[variable].dropna()
        if variable not in ("Genres"):
            corpus = corpus.map(lambda x: x.replace(",", "").split(" "))
            corpus = corpus.map(lambda x: [word for word in x if len(word) > 3])
        corpus = ",".join(word for word_list in corpus for word in word_list)
        wordcloud = WordCloud(max_font_size=None, background_color="white", collocations=False, width=1500, height=1500).generate(corpus)
        ax[i].imshow(wordcloud)
        ax[i].set_title(variable)
        ax[i].axis("off")
    plt.show()

word_cloud(["Genres", "Subtitle", "Description"])

# %%
# Games, Strategy, Entertainment and Simulation are the most popular genres.
# Strategy, Battle and Puzzle are the most frequently used words in subtitles.

# %%
df["Age Rating"].value_counts().plot.pie(autopct="%1.1f", explode=[0,0,0.1,0], figsize=(6,6))
plt.title("Age Rating wise app proportions")
# Out:
# Text(0.5, 1.0, 'Age Rating wise app proportions')

# %%
# Age rating 4+ has the highest proportion of apps.
# Age rating 17+ has the least proportion of apps.
# As age rating increases, proportion of apps decreases.

# %%
# INFERENCES

# Removed the null values by substituting the mean and checked mull values using heatmaps
# Found that the most common genres are Games,Strategy and Simulation

# Dropped unnecessary columns, searched for missing values in each column and scanned for junk values as part of data cleaning and preparation.
# Done a simple analysis on the basis of genre against user rating, age rating, size, price. 
# Games genre is much more significant than others.
# Age rating 4+ has the highest proportion of apps.
